# %%
# this mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

FOLDERNAME = "ConicalClassificationGithub"
assert FOLDERNAME is not None, "[!] Enter the foldername."

import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# %cd drive/My\ Drive
# %cd $FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# /content/drive/My Drive/ConicalClassificationGithub

# %%
from sklearn.datasets import load_files
import codecs as cs
from load_dataset import *

X_train, y_train, X_valid, y_valid, X_test, y_test = load_and_split()

# %%
from NE_TF import NE_TF

ne_tf = NE_TF()
ne_tf.fit(X_train)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
from sklearn.svm import OneClassSVM
from sklearn.metrics import *

svm = OneClassSVM(kernel="linear")
svm.fit(ne_tf.transform(X_train).toarray())

y_pred = svm.predict(ne_tf.transform(X_valid).toarray())
y_pred[y_pred < 0] = 0
print(f"Validation accuracy: {accuracy_score(y_valid, y_pred)}")

y_pred = svm.predict(ne_tf.transform(X_test).toarray())
y_pred[y_pred < 0] = 0
print(f"Testing accuracy: {accuracy_score(y_test, y_pred)}")
# Out:
# Validation accuracy: 0.9999187470799732
# Testing accuracy: 0.9998578131665008
